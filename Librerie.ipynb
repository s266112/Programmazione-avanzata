# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import scipy
import line_profiler
import cffi
import cython

# %%
import sys
print("Python:", sys.version)

librerie = {
    'numpy': 'np',
    'PIL': None,
    'matplotlib': 'plt',
    'scipy': None,
    'line_profiler': None,
    'cffi': None,
    'cython': None
}

for lib, alias in librerie.items():
    try:
        if alias:
            __import__(lib)
            print(f"✅ {lib} - OK")
        else:
            __import__(lib)
            print(f"✅ {lib} - OK")
    except ImportError:
        print(f"❌ {lib} - MANCANTE")
# Out:
# Python: 3.14.4 (main, Jun 18 2026, 14:25:02) [GCC 15.2.0]
# ✅ numpy - OK
# ✅ PIL - OK
# ✅ matplotlib - OK
# ✅ scipy - OK
# ✅ line_profiler - OK
# ✅ cffi - OK
# ✅ cython - OK
